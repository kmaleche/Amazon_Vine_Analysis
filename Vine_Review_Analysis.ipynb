# %%
import pandas as pd

# %%
df = pd.read_csv('vine_table.csv')
df.head()
# Out:
#         review_id  star_rating  helpful_votes  total_votes vine  \
# 0  R3P2HIOQCIN5ZU            1              0            0    N
# 1  R12VVR0WH5Q24V            5              0            0    N
# 2   RNCCKB6TV5EEF            4              0            0    N
# 3  R2NZXYIVCGB13W            5              0            6    N
# 4  R2EQ1TG9IT3OEQ            3              0            0    N
#
#   verified_purchase
# 0                 Y
# 1                 Y
# 2                 Y
# 3                 Y
# 4                 Y

# %%
helpful_df = df[df['total_votes'] >= 20]

# %%
helpful_df.head()
# Out:
#            review_id  star_rating  helpful_votes  total_votes vine  \
# 406   R37F42INKX7L9K            5             45           49    N
# 881   R2EHKYNEP8WVSR            5             25           25    N
# 884    RXOS7BHID0UHL            5             16           27    N
# 1585  R36PQ9D8L2AAOH            5             30           32    N
# 1777  R33HHGFPB403GM            5             19           21    N
#
#      verified_purchase
# 406                  Y
# 881                  Y
# 884                  N
# 1585                 Y
# 1777                 Y

# %%
ratio_df = helpful_df[helpful_df['helpful_votes'] / helpful_df['total_votes'] >= 0.5]

# %%
ratio_df['vine'].value_counts()
# Out:
# N    27342
# Y       22
# Name: vine, dtype: int64

# %%
# Filter the DataFrame or table created in Step 2, and create a new DataFrame or table that 
# retrieves all the rows where a review was written as part of the Vine program (paid), vine == 'Y'.

paid = ratio_df[ratio_df['vine'] == 'Y']

# %%
paid
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 419435   R2N45ZKRRZS856            5             21           22    Y
# 455762    R5OMLMK13A8NS            5             34           38    Y
# 1199246  R2MPEQ4SPTEQNS            4            180          184    Y
# 1373812   RIR0D3KJ0CQ31            4             21           21    Y
# 1380829  R1SPWJDHUWWC5E            5             88           98    Y
# 1392112  R1X6M5XA3FT98W            5             24           26    Y
# 1417450  R37VCW6HA0Z72T            5             27           28    Y
# 1439645  R2XRYNV2SY3ZKL            5             53           56    Y
# 1461645  R1Y93KWKAX1P5N            2             26           31    Y
# 1462000  R2QVTDYYLTP8SL            5             21           24    Y
# 1464680  R3KOK2SH39BZU1            3             94           96    Y
# 1468874  R2VOM73EHLPXJW            4             35           38    Y
# ...

# %%
# Repeat Step 3, but this time retrieve all the rows where the 
# review was not part of the Vine program (unpaid), vine == 'N'.

unpaid = ratio_df[ratio_df['vine'] == 'N']

# Determine the total number of reviews, the number of 5-star reviews, and 
# the percentage of 5-star reviews for the two types of review (paid vs unpaid).

total = ratio_df['vine'].count()
five_star = len(ratio_df[ratio_df['star_rating']==5])

paid_total = len(paid)
unpaid_total = len(unpaid)

# %%
paid_counts = paid['star_rating'].value_counts()
percentage_paid = (paid_counts.iloc[0] / paid_total)*100

# %%
print(f'percentage of paid 5-star reviews: {percentage_paid}')
# Out:
# percentage of paid 5-star reviews: 59.09090909090909

# %%
unpaid_counts = unpaid['star_rating'].value_counts()
percentage_unpaid = (unpaid_counts.iloc[0] / unpaid_total)*100
print(f'percentage of unpaid 5-star teviews: {percentage_unpaid}')
# Out:
# percentage of unpaid 5-star teviews: 53.26969497476411
